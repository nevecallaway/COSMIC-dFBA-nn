# %%
# !cd /content && git clone https://github.com/nevecallaway/COSMIC-dFBA-nn.git 2>/dev/null || (cd /content/COSMIC-dFBA-nn && git pull)
# %cd /content/COSMIC-dFBA-nn/nn
# Out:
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 4 (delta 2), reused 4 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 3.26 KiB | 1.63 MiB/s, done.
# From https://github.com/nevecallaway/COSMIC-dFBA-nn
#    0a7da77..05495f9  main       -> origin/main
# Updating 0a7da77..05495f9
# Fast-forward
#  nn/evaluate_auc.py | 275 +++++++++++++++++++++++++++++++++++++++++++++++++++++
#  1 file changed, 275 insertions(+)
#  create mode 100644 nn/evaluate_auc.py
# /content/COSMIC-dFBA-nn/nn

# %%
# !python train_heteroscedastic.py
# Out:
# ...
# HETEROSCEDASTIC MULTI-TASK MODEL
# Tasks: Phase prediction + Concentration prediction with uncertainty
# ...
#
# Component weights (to prevent abandoning easy targets):
#   Cell Density   : 0.8225
#   Glucose        : 1.3236
#   Lactate        : 1.2476
#   Titer          : 0.6064
#
#
# Loading real experimental data from data_2.csv
# Found 10 reactors: ['R0001', 'R0002', 'R0003', 'R0004', 'R0005', 'R0006', 'R0008', 'R0010', 'R0011', 'R0012']
#   ✓ R0001: 13 timepoints, IC=[0.04094333 0.4777097  0.07085792 0.03898601], Phase range: 0.000-1.000
#   ✓ R0002: 13 timepoints, IC=[0.07649818 0.24994572 0.12226991 0.02969091], Phase range: 0.000-1.000
#   ✓ R0003: 13 timepoints, IC=[0.24674287 1.         0.30165682 0.02372998], Phase range: 0.000-1.000
#   ✓ R0004: 13 timepoints, IC=[0.03429213 1.         0.1200109  0.04064132], Phase range: 0.000-1.000
#   ✓ R0005: 13 timepoints, IC=[0.25100083 0.24776306 0.14059353 0.02524839], Phase range: 0.000-1.000
# ...

# %%
# !python evaluate_heteroscedastic.py
# Out:
# ...
# MODEL COMPARISON: HETEROSCEDASTIC vs SIMPLE BASELINE
# ...
#
#
# Loading real experimental data from data_2.csv
# Found 10 reactors: ['R0001', 'R0002', 'R0003', 'R0004', 'R0005', 'R0006', 'R0008', 'R0010', 'R0011', 'R0012']
#   ✓ R0001: 13 timepoints, IC=[0.04094333 0.4777097  0.07085792 0.03898601], Phase range: 0.000-1.000
#   ✓ R0002: 13 timepoints, IC=[0.07649818 0.24994572 0.12226991 0.02969091], Phase range: 0.000-1.000
#   ✓ R0003: 13 timepoints, IC=[0.24674287 1.         0.30165682 0.02372998], Phase range: 0.000-1.000
#   ✓ R0004: 13 timepoints, IC=[0.03429213 1.         0.1200109  0.04064132], Phase range: 0.000-1.000
#   ✓ R0005: 13 timepoints, IC=[0.25100083 0.24776306 0.14059353 0.02524839], Phase range: 0.000-1.000
#   ✓ R0006: 13 timepoints, IC=[0.15734674 0.26702501 0.11814477 0.03446796], Phase range: 0.000-1.000
#   ✓ R0008: 13 timepoints, IC=[0.04227081 0.5015855  0.0547631  0.01380685], Phase range: -0.000-1.000
# ...

# %%
# Download model from Colab
from google.colab import files
files.download('heteroscedastic_model.pt')

# %%
# !python plot_comparison.py
# Out:
# Loading real experimental data from data_2.csv
# Found 10 reactors: ['R0001', 'R0002', 'R0003', 'R0004', 'R0005', 'R0006', 'R0008', 'R0010', 'R0011', 'R0012']
#   ✓ R0001: 13 timepoints, IC=[0.04094333 0.4777097  0.07085792 0.03898601], Phase range: 0.000-1.000
#   ✓ R0002: 13 timepoints, IC=[0.07649818 0.24994572 0.12226991 0.02969091], Phase range: 0.000-1.000
#   ✓ R0003: 13 timepoints, IC=[0.24674287 1.         0.30165682 0.02372998], Phase range: 0.000-1.000
#   ✓ R0004: 13 timepoints, IC=[0.03429213 1.         0.1200109  0.04064132], Phase range: 0.000-1.000
#   ✓ R0005: 13 timepoints, IC=[0.25100083 0.24776306 0.14059353 0.02524839], Phase range: 0.000-1.000
#   ✓ R0006: 13 timepoints, IC=[0.15734674 0.26702501 0.11814477 0.03446796], Phase range: 0.000-1.000
#   ✓ R0008: 13 timepoints, IC=[0.04227081 0.5015855  0.0547631  0.01380685], Phase range: -0.000-1.000
#   ✓ R0010: 13 timepoints, IC=[0.09359349 0.47154646 0.09045789 0.02017145], Phase range: 0.000-1.000
# ...

# %%
# !python evaluate_auc.py
# Out:
# ...
# AUC ANALYSIS: Binary Classification at Multiple Thresholds
# ...
#
#
# Loading real experimental data from data_2.csv
# Found 10 reactors: ['R0001', 'R0002', 'R0003', 'R0004', 'R0005', 'R0006', 'R0008', 'R0010', 'R0011', 'R0012']
#   ✓ R0001: 13 timepoints, IC=[0.04094333 0.4777097  0.07085792 0.03898601], Phase range: 0.000-1.000
#   ✓ R0002: 13 timepoints, IC=[0.07649818 0.24994572 0.12226991 0.02969091], Phase range: 0.000-1.000
#   ✓ R0003: 13 timepoints, IC=[0.24674287 1.         0.30165682 0.02372998], Phase range: 0.000-1.000
#   ✓ R0004: 13 timepoints, IC=[0.03429213 1.         0.1200109  0.04064132], Phase range: 0.000-1.000
#   ✓ R0005: 13 timepoints, IC=[0.25100083 0.24776306 0.14059353 0.02524839], Phase range: 0.000-1.000
#   ✓ R0006: 13 timepoints, IC=[0.15734674 0.26702501 0.11814477 0.03446796], Phase range: 0.000-1.000
#   ✓ R0008: 13 timepoints, IC=[0.04227081 0.5015855  0.0547631  0.01380685], Phase range: -0.000-1.000
# ...
