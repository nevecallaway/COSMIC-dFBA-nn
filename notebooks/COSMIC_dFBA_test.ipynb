# %%
# !pip install torch numpy scipy matplotlib -q
# !git clone https://github.com/nevecallaway/COSMIC-dFBA-nn
# Out:
# fatal: destination path 'COSMIC-dFBA-nn' already exists and is not an empty directory.

# %%
# !cd /content/COSMIC-dFBA-nn && git pull
# Out:
# Already up to date.

# %%
import os
os.chdir('/content/COSMIC-dFBA-nn')
# %run nn/test_demo_enhanced.py
# Out:
# ...
# COSMIC dFBA Enhanced Neural Network Surrogate - Demo
# With Multi-Output Heads and Phase Transitions
# ...
#
# ...
# Creating Synthetic Data (Enhanced)
# ...
# Simulations: 30, Timepoints: 150, Components: 4
# ✓ Generated 30 synthetic trajectories with phase transitions
#
# ...
# Training Enhanced Neural Network Surrogate
# ...
# Train: 24, Validation: 6
# Device: cpu
# Model parameters: 135,277
# Model outputs: concentrations, phase_weights, growth_rates, prod_rates
# Epoch 1: Train Loss = 0.093762, Val Loss = 0.078435 (BEST)
# Epoch 2: Train Loss = 0.071478, Val Loss = 0.059892 (BEST)
# Epoch 3: Train Loss = 0.060764, Val Loss = 0.059583 (BEST)
# Epoch 4: Train Loss = 0.062146, Val Loss = 0.058424 (BEST)
# Epoch 5: Train Loss = 0.060396, Val Loss = 0.058256 (BEST)
# Epoch 6: Train Loss = 0.058527, Val Loss = 0.057726 (BEST)
# Epoch 7: Train Loss = 0.057927, Val Loss = 0.056372 (BEST)
# Epoch 8: Train Loss = 0.055382, Val Loss = 0.054983 (BEST)
# Epoch 9: Train Loss = 0.052511, Val Loss = 0.055330
# ...
